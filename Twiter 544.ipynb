# %% [markdown]
# #Twitter data mining.
# # here the twitter data  stream is generated for the tweetes related to trump and the stored in the file, processed, and finally the data mining is done,data is stored in sqlite db

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
from tweepy import TweepError
import json
import sqlite3
import datetime as dt
# from Authentication import authentication

#create the connection with 'tweet2.db' database as 'con'
con = sqlite3.connect('tweet2.db')

#creates cursor on connection as 'c'
c = con.cursor()

def create_cand_table():
    c.execute('''CREATE TABLE IF NOT EXISTS candidateTable(date TEXT, tweet TEXT, user TEXT)''')

def create_tweet_table():
    c.execute('''CREATE TABLE IF NOT EXISTS tweetTable(created_at TEXT, tweet TEXT, user TEXT)''')

consumer_key = 'mBhnrL7jjl80KhL2NiHbmQTba'
consumer_secret = '4tGjiBJQac3t43rqiU8W8sRzUFVwZJjjJa5KGGKwpRlHSyHqQD'
access_token = '2598113214-G1C9CQV2Du7ZnMKy1fMvIz2R06dYbXmGVGbgY1p'
access_secret = 'GiwmMK6VV7oYILGR7LiumO0U7QNcDHxXojZOUxkYD98O2'



class Listener(StreamListener):
    def on_data(self, data):
        whole_data = json.loads(data)
        tweet = whole_data["text"]
        date = dt.datetime.strptime(whole_data['created_at'], "%a %b %d %H:%M:%S %z %Y")
        clean_date = date.replace(second=0, microsecond=0, tzinfo=None)
        FinalDate = clean_date.strftime('%Y-%m-%d %H:%M')
        user = whole_data["user"]["screen_name"]
        c.execute("INSERT INTO tweetTable (created_at, tweet, user) VALUES (?,?,?)", (FinalDate, tweet, user))
        con.commit()

        print(data)
        savefile = open('output.txt', 'a', encoding='utf-8')
        savefile.write(data)
        savefile.write('\n')
        savefile.close()
        return True

    def on_error(self, status):
        print(status)



def execute_streaming():
    try:
        print('Success! Connected.')
        search_list = []
        n = int(input('How many keywords you want to search?'))
        for x in range(n):
            search_keyword = input('Enter the key you want search for: ')
            search_list.append(search_keyword)
            print(str(search_list))
        auth = OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_secret)
        twitterStream = Stream(auth, Listener())
        twitterStream.filter(track=search_list)
    except TweepError as e:
        print(e.response.status)

# %%
create_tweet_table()
execute_streaming()
# Out:
# Success! Connected.
# How many keywords you want to search?1
# Enter the key you want search for: Arsenal
# ['Arsenal']
# {"created_at":"Fri Apr 27 01:42:31 +0000 2018","id":989681162011332609,"id_str":"989681162011332609","text":"RT @joserra_espn: El Atl\u00e9tico de Madrid hace un partido heroico en Londres, jugando con 10 hombres desde el minuto 10. En el 2o tiempo el A\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2960038177,"id_str":"2960038177","name":"Saldierna\ud83d\udc36","screen_name":"FilyBoy94","location":null,"url":null,"description":"B\u00e1sicamente Ted Mosby con el humor de Ross Geller que usa el sarcasmo de Chandler Bing.","translator_type":"none","protected":false,"verified":false,"followers_count":42,"friends_count":350,"listed_count":0,"favourites_count":16080,"statuses_count":9523,"created_at":"Mon Jan 05 19:52:53 +0000 2015","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"ABB8C2","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/986232384444968961\/tAp5IS6w_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/986232384444968961\/tAp5IS6w_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/2960038177\/1524281439","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Fri Apr 27 01:31:34 +0000 2018","id":989678409973252097,"id_str":"989678409973252097","text":"El Atl\u00e9tico de Madrid hace un partido heroico en Londres, jugando con 10 hombres desde el minuto 10. En el 2o tiemp\u2026 https:\/\/t.co\/EGGV4eBBoa","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id
geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/pbs.twimg.com\/profile_background_images\/628164700036050944\/xUexB3Jq.jpg","profile_background_image_url_https":"https:\/\/pbs.twimg.com\/profile_background_images\/628164700036050944\/xUexB3Jq.jpg","profile_background_tile":false,"profile_link_color":"0084B4","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/854433469216296962\/iLsIgs88_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/854433469216296962\/iLsIgs88_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1561 ...
#
# ...
#
# {"created_at":"Fri Apr 27 01:45:43 +0000 2018","id":989681968336916480,"id_str":"989681968336916480","text":"RT @utdxtra: Milly Rock and Take the L in the same season at the Emirates. Banter level: Arsenal. \ud83d\ude02 https:\/\/t.co\/b6ThNPxJPU","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1464059916,"id_str":"1464059916","name":"MANCHESTER ARE UNITED","screen_name":"rico_utd95","location":"100% FOLLOW BACK. RESPECT ALL","url":null,"description":"Die hard @ManUtd fan since 2009 \ud83d\udc4a\ud83c\udffc \u2022 #MUFC_FAMILY from \ud83c\uddee\ud83c\udde9 \u2022 Sharing all about \u26bd\ufe0f \u2022 Unfollow me = unfollow you too \u274c \u2022 Fight till the end, United lads!!! \ud83d\ude08\u270a","translator_type":"none","protected":false,"verified":false,"followers_count":1775,"friends_count":3430,"listed_count":8,"favourites_count":23986,"statuses_count":35927,"created_at":"Tue May 28 07:38:46 +0000 2013","utc_offset":25200,"time_zone":"Jakarta","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/pbs.twimg.com\/profile_background_images\/590601423810727936\/BBNMNw7w.jpg","profile_background_image_url_https":"https:\/\/pbs.twimg.com\/profile_background_images\/590601423810727936\/BBNMNw7w.jpg","profile_background_tile":true,"profile_link_color":"E70705","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/988885991736799234\/VJsVq3kV_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/988885991736799234\/VJsVq3kV_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1464059916\/1523997293","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Apr 26 21:17:48 +0000 2018","id":989614547463036930,"id_str":"989614547463036930","text":"Milly Rock and Take the L in the same season at the Emirates. Banter level: Arsenal. \ud83d\ude02 https:\/\/t.co\/b6ThNPxJPU","display_text_range":[0,86],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2196205482,"id_str":"2196205482","name":"United Xtra","screen_name":"utdxtra","location":"Manchester, England","url":null,"description":"The #1 source for everything #mufc. Follow for updates.","translator_type":"none","protected":false,"verified":false,"followers_count":87502,"friends_count":111,"listed_count":624,"favourites_count":5456,"statuses_count":15152,"created_at":"Fri Nov 15 15:55:18 +0000 2013","utc_offset":3600,"time_zone":"London","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"ABB8C2","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/959949566782124033\/Kmx6rQBe_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/9599495667821240 ...
# {"created_at":"Fri Apr 27 01:45:45 +0000 2018","id":989681976604020736,"id_str":"989681976604020736","text":"Yo que crei que si segu\u00eda as\u00ed no iba a ir ma\u00f1ana a arsenal. Primera vez que mi hermana quiere ir y me enfermo gua'u jajaja","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":531531175,"id_str":"531531175","name":"Alicia \ud83c\udf1e","screen_name":"Aliperez_99","location":"EnunmundoParalelo ","url":null,"description":"Todos somos estrellas perdidas intentando brillar en la obscuridad..\nDerecho-UNA","translator_type":"none","protected":false,"verified":false,"followers_count":2683,"friends_count":2102,"listed_count":24,"favourites_count":16212,"statuses_count":98966,"created_at":"Tue Mar 20 18:42:54 +0000 2012","utc_offset":-10800,"time_zone":"Brasilia","geo_enabled":true,"lang":"es","contributors_enabled":false,"is_translator":false,"profile_background_color":"020812","profile_background_image_url":"http:\/\/pbs.twimg.com\/profile_background_images\/378800000119639657\/6e05a48d548fcc6a2ebda6658d7ea447.jpeg","profile_background_image_url_https":"https:\/\/pbs.twimg.com\/profile_background_images\/378800000119639657\/6e05a48d548fcc6a2ebda6658d7ea447.jpeg","profile_background_tile":false,"profile_link_color":"3B94D9","profile_sidebar_border_color":"2280A9","profile_sidebar_fill_color":"020812","profile_text_color":"2280A9","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/989584242907799552\/mwFGjF0Q_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/989584242907799552\/mwFGjF0Q_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/531531175\/1458093473","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":"es","timestamp_ms":"1524793545281"}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1624             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1625         self._raise_ssl_error(self._ssl, result)
#    1626
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1430         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1431             raise WantReadError()
#    1432         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-fe97a0efc608> in <module>()
#       1 create_tweet_table()
# ----> 2 execute_streaming()
#
# <ipython-input-4-0410dba9e96b> in execute_streaming()
#      63         auth.set_access_token(access_token, access_secret)
#      64         twitterStream = Stream(auth, Listener())
# ---> 65         twitterStream.filter(track=search_list)
#      66     except TweepError as e:
#      67         print(e.response.status)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:
